# %%
import pandas as pd
import urllib.request
import json
import ast
from pandas.io.json import json_normalize

# %%
# open list of all jobs with uuid
with urllib.request.urlopen("http://api.dataatwork.org/v1/jobs/29-2031.00") as url:
    data = json.loads(url.read().decode())
    print(data)
# Out:
# {'uuid': 'ad9812f91f3670f1ab3420c43821eafe', 'onet_soc_code': '29-2031.00', 'title': 'Cardiovascular Technologists and Technicians', 'description': 'Conduct tests on pulmonary or cardiovascular systems of patients for diagnostic purposes. May conduct or assist in electrocardiograms, cardiac catheterizations, pulmonary functions, lung capacity, and similar tests. Includes vascular technologists.', 'related_job_titles': [{'uuid': 'a1e4a57509a7c77e8d02d04866a5b889', 'title': 'ARRT Technologist (American Registry of Radiologic Technologists Technologist)'}, {'uuid': 'b6c4f4d7676e9c1e4c2bca5fab118997', 'title': 'Cardiac Catheterization Laboratory Technologist'}, {'uuid': '6de88736305bc66381b555be2c8c79e8', 'title': 'Cardiac Catheterization Special Procedures Technologist'}, {'uuid': 'd3afc1d82c5d301c132c17b681637de0', 'title': 'Cardiac Catheterization Technician'}, {'uuid': '58d470fce6a6255d9df458171baefcd1', 'title': 'Cardiac Catheterization Technologist'}, {'uuid': 'febb6f407269952298cdce46072d5bc8', 'title': 'Cardiac Technician'}, {'uuid': '6f91d402837db9e9c43b3942b153116d', 'title': 'Cardiograph Operator'}, {'uuid': 'd4b9f4f6a4e5e17a590a84bef3e36ce9', 'title': 'Cardiographer'}, {'uuid': '3d89a140a25182d0596ee43189493830', 'title': 'Cardiology Technician'}, {'uuid': '891d3b482efc70533a966ed12509cd58', 'title': 'Cardiology Technologist'}, {'uuid': '0305e7b921dc08b567de3545a29d58c5', 'title': 'Cardiopulmonary Technician'}, {'uuid': '8ed7a7ffcf51e93c0d7fe5acc157630e', 'title': 'Cardiopulmonary Technologist'}, {'uuid': 'de6b8e272837503ffcf49cb0c8032ea9', 'title': 'Cardiovascular Invasive Specialist'}, {'uuid': 'aec0903f78866181d2d426fcf564dc9a', 'title': 'Cardiovascular Radiologic Technologist'}, {'uuid': 'a93cc0606d0f145197fcb1fc308bf50b', 'title': 'Cardiovascular Technician'}, {'uuid': 'cc583b8f4e0c449012bb046eff565601', 'title': 'Cardiovascular Technologist (CVT)'}, {'uuid': '3b883fbf522d74421c9ff028f6003cd8', 'title': 'Cath Lab Radiological Technologist (Catheterization Laboratory Radiological Technologist)'}, {'uuid': '59b65cbd268a4b25d3f8a3209e90ac81', 'title': 'Computed Tomography Technologist (CTT)'}, {'uuid': '6e8618a406510888291a0bc86e163c9f', 'title': 'EEG Technician (Electroencephalogram Technician)'}, {'uuid': 'f832b34117bdf0c84ae2283333685a53', 'title': 'EKG/ECG Technician (Electrocardiogram Technician)'}, {'uuid': '1ce4e404236bf9a7c7578f9beeb4d0c8', 'title': 'Electrocardiogram Technician (EKG Technician)'}, {'uuid': '45f2ca83c4d95b47b836848c9b4f510d', 'title': 'Electrocardiograph Operator'}, {'uuid': '9f55c3f1523e1071a77fc758d606eb11', 'title': 'Electrocardiograph Technician'}, {'uuid': '9a602f97ffe11480a235bf02a8f3eeb9', 'title': 'Electrocardiographic Technician'}, {'uuid': 'e6b2fd3e1c9a329e5daadc9baf335e66', 'title': 'Holter Scanning Technician'}, {'uuid': 'bb37c41741f9db6170dc6722192a3895', 'title': 'Invasive Cardiovascular Technologist'}, {'uuid': '3e7c937f202c4b63ccbc242e8981ae42', 'title': 'Monitor Technician'}, {'uuid': '902cd7215b99cb7a4401e3c1cb5aa271', 'title': 'Nuclear Medicine Technologist'}, {'uuid': 'fb33d9cf8330681c355308b06ef3c1b6', 'title': 'Pulmonary Function Technician'}, {'uuid': '274f039aa04d1038aadf8c9fd8872f17', 'title': 'Pulmonary Function Technologist'}, {'uuid': 'd9d0d8aadda7f0bc9ad2662bf4f877dc', 'title': 'Registered Cardiovascular Invasive Specialist (RCIS)'}, {'uuid': '5160d97a7611f0caa4d6839ac0f99490', 'title': 'Telemetry Technician'}, {'uuid': '32ea0f6fd190c6b5984906076aefbdb8', 'title': 'Vascular Technologist'}, {'uuid': '34f5b7ee1ce21171632135fc90a00e9a', 'title': 'Laboratory Technologist (Lab Technologist)'}], 'unusual_job_titles': []}

# %%
# api request for skills data related to the first job 'cardiovascular technologists and technicians'
with urllib.request.urlopen(
    "http://api.dataatwork.org/v1/jobs/ad9812f91f3670f1ab3420c43821eafe/related_skills") as url:
    data_test = json.loads(url.read().decode())
    print(data_test)
# Out:
# {'job_uuid': 'ad9812f91f3670f1ab3420c43821eafe', 'job_title': 'Cardiovascular Technologists and Technicians', 'normalized_job_title': 'cardiovascular technologists and technicians', 'skills': [{'skill_uuid': 'b4595c0fed78ae278f4cb5eff45bba24', 'skill_name': 'customer and personal service', 'skill_type': 'knowledge', 'description': 'knowledge of principles and processes for providing customer and personal services. this includes customer needs assessment, meeting quality standards for services, and evaluation of customer satisfaction.', 'normalized_skill_name': 'customer and personal service', 'importance': 4.29, 'level': 5.0}, {'skill_uuid': 'd66da8698b5a37186143205b78c73f7d', 'skill_name': 'problem sensitivity', 'skill_type': 'ability', 'description': 'the ability to tell when something is wrong or is likely to go wrong. it does not involve solving the problem, only recognizing there is a problem.', 'normalized_skill_name': 'problem sensitivity', 'importance': 4.12, 'level': 4.12}, {'skill_uuid': '0194023051cb666af3d2c4761d894957', 'skill_name': 'oral comprehension', 'skill_type': 'ability', 'description': 'the ability to listen to and understand information and ideas presented through spoken words and sentences.', 'normalized_skill_name': 'oral comprehension', 'importance': 4.0, 'level': 4.0}, {'skill_uuid': 'd3dfdcdd96e1a57645c3b1728c640ee2', 'skill_name': 'oral expression', 'skill_type': 'ability', 'description': 'the ability to communicate information and ideas in speaking so others will understand.', 'normalized_skill_name': 'oral expression', 'importance': 4.0, 'level': 4.0}, {'skill_uuid': '40d7109449763956696e4e2ef537a281', 'skill_name': 'near vision', 'skill_type': 'ability', 'description': 'the ability to see details at close range (within a few feet of the observer).', 'normalized_skill_name': 'near vision', 'importance': 4.0, 'level': 3.62}, {'skill_uuid': '16b3f6e445161762cd3fdf593c1d373a', 'skill_name': 'medicine and dentistry', 'skill_type': 'knowledge', 'description': 'knowledge of the information and techniques needed to diagnose and treat human injuries, diseases, and deformities. this includes symptoms, treatment alternatives, drug properties and interactions, and preventive health-care measures.', 'normalized_skill_name': 'medicine and dentistry', 'importance': 3.89, 'level': 4.06}, {'skill_uuid': 'a636cb69257dcec699bce4f023a05126', 'skill_name': 'active listening', 'skill_type': 'skill', 'description': 'giving full attention to what other people are saying, taking time to understand the points being made, asking questions as appropriate, and not interrupting at inappropriate times.', 'normalized_skill_name': 'active listening', 'importance': 3.88, 'level': 3.88}, {'skill_uuid': '500018df958f2b9f8b387cf5637a0a04', 'skill_name': 'english language', 'skill_type': 'knowledge', 'description': 'knowledge of the structure and content of the english language including the meaning and spelling of words, rules of composition, and grammar.', 'normalized_skill_name': 'english language', 'importance': 3.87, 'level': 3.44}, {'skill_uuid': 'd1715efc5a67ac1c988152b8136e3dfa', 'skill_name': 'speaking', 'skill_type': 'skill', 'description': 'talking to others to convey information effectively.', 'normalized_skill_name': 'speaking', 'importance': 3.75, 'level': 3.62}, {'skill_uuid': '20784bf09c9fe614603ad635e6093ede', 'skill_name': 'critical thinking', 'skill_type': 'skill', 'description': 'using logic and reasoning to identify the strengths and weaknesses of alternative solutions, conclusions or approaches to problems.', 'normalized_skill_name': 'critical thinking', 'importance': 3.75, 'level': 3.75}, {'skill_uuid': '89948c7f4890af5ff18524b4fc3f3611', 'skill_name': 'monitoring', 'skill_type': 'skill', 'description': 'monitoring/assessing performance of yourself, other individuals, or organizations to make improvements or take corrective action.', 'normalized_skill_name': 'monitoring', 'importance': 3.75, 'level': 3.75}, {' ...

# %%
skills_data = json_normalize(data=data_test['skills'])
skills_data.head(10)
# Out:
#                                          description  importance  level  \
# 0  knowledge of principles and processes for prov...        4.29   5.00
# 1  the ability to tell when something is wrong or...        4.12   4.12
# 2  the ability to listen to and understand inform...        4.00   4.00
# 3  the ability to communicate information and ide...        4.00   4.00
# 4  the ability to see details at close range (wit...        4.00   3.62
# 5  knowledge of the information and techniques ne...        3.89   4.06
# 6  giving full attention to what other people are...        3.88   3.88
# 7  knowledge of the structure and content of the ...        3.87   3.44
# 8  talking to others to convey information effect...        3.75   3.62
# 9  using logic and reasoning to identify the stre...        3.75   3.75
#
#            normalized_skill_name                     skill_name skill_type  \
# 0  customer and personal service  customer and personal service  knowledge
# 1            problem sensitivity            problem sensitivity    ability
# 2             oral comprehension             oral comprehension    ability
# 3                oral expression                oral expression    ability
# 4                    near vision                    near vision    ability
# 5         medicine and dentistry         medicine and dentistry  knowledge
# 6               active listening               active listening      skill
# 7               english language               english language  knowledge
# 8                       speaking                       speaking      skill
# 9              critical thinking              critical thinking      skill
#
#                          skill_uuid
# 0  b4595c0fed78ae278f4cb5eff45bba24
# 1  d66da8698b5a37186143205b78c73f7d
# 2  0194023051cb666af3d2c4761d894957
# 3  d3dfdcdd96e1a57645c3b1728c640ee2
# 4  40d7109449763956696e4e2ef537a281
# 5  16b3f6e445161762cd3fdf593c1d373a
# 6  a636cb69257dcec699bce4f023a05126
# 7  500018df958f2b9f8b387cf5637a0a04
# 8  d1715efc5a67ac1c988152b8136e3dfa
# 9  20784bf09c9fe614603ad635e6093ede

# %%
from collections import Counter
results = Counter()
skills_data['description'].str.lower().str.split().apply(results.update)
print(results)
# Out:
# Counter({'and': 167, 'the': 123, 'to': 111, 'of': 103, 'or': 75, 'ability': 53, 'knowledge': 32, 'a': 28, 'in': 27, 'for': 22, 'your': 14, 'information': 13, 'is': 12, 'other': 12, 'their': 11, 'principles': 9, 'this': 9, 'includes': 9, 'quickly': 9, 'with': 9, 'when': 8, 'time': 8, 'as': 8, 'including': 8, 'ideas': 7, 'others': 7, 'rules': 7, 'methods': 7, 'equipment': 7, 'two': 7, 'human': 6, 'make': 6, 'it': 5, 'understand': 5, 'will': 5, 'see': 5, 'techniques': 5, 'needed': 5, 'people': 5, 'using': 5, 'one': 5, 'on': 5, 'how': 5, 'between': 5, 'procedures': 5, 'body': 5, 'determining': 5, 'production': 5, 'objects': 5, 'not': 4, 'presented': 4, 'at': 4, 'are': 4, 'words,': 4, 'understanding': 4, 'they': 4, 'that': 4, 'actions': 4, 'differences': 4, 'equipment,': 4, 'ways': 4, 'appropriate': 4, 'while': 4, 'systems.': 4, 'over': 4, 'movements': 4, 'repeatedly': 4, 'solve': 4, 'do': 4, 'use': 4, 'different': 4, 'more': 4, 'arms,': 4, 'principles,': 4, 'techniques,': 4, 'muscle': 4, 'processes': 3, 'customer': 3, 'services.': 3, 'needs': 3, 'quality': 3, 'tell': 3, 'problem.': 3, 'so': 3, 'what': 3, 'being': 3, 'identify': 3, 'problems.': 3, 'work': 3, 'writing': 3, 'things': 3, 'numbers,': 3, 'pictures,': 3, 'be': 3, 'object.': 3, 'teaching': 3, 'relative': 3, 'choose': 3, 'detect': 3, 'hand': 3, 'arm': 3, 'moving': 3, 'identifying': 3, 'without': 3, 'hand,': 3, 'together': 3, 'objects.': 3, 'relation': 3, 'about': 3, 'procedures,': 3, 'systems': 3, 'such': 3, 'physical': 3, 'involved': 3, 'methods,': 3, 'exert': 3, 'force': 3, 'and/or': 3, 'legs.': 3, 'movement': 3, 'which': 3, 'an': 3, 'services,': 2, 'something': 2, 'does': 2, 'involve': 2, 'communicate': 2, 'understand.': 2, 'details': 2, 'treatment': 2, 'properties': 2, 'interactions,': 2, 'structure': 2, 'content': 2, 'language': 2, 'meaning': 2, 'spelling': 2, 'composition,': 2, 'alternative': 2, 'conclusions': 2, 'performance': 2, 'indicators': 2, 'machine': 2, 'related': 2, "others'": 2, 'general': 2, 'specific': 2, 'problems': 2, 'among': 2, 'you.': 2, 'certain': 2, 'pattern': 2, 'letters,': 2, 'mathematical': 2, 'sets': 2, 'patterns.': 2, 'after': 2, 'object': 2, 'computer': 2, 'applications': 2, 'training': 2, 'looking': 2, 'costs': 2, 'distracting': 2, 'keep': 2, 'position.': 2, 'new': 2, 'both': 2, 'develop': 2, 'evaluate': 2, 'operations': 2, 'move': 2, 'hands': 2, 'grasp,': 2, 'manipulate,': 2, 'assemble': 2, 'managing': 2, "one's": 2, 'back': 2, 'activities': 2, 'sounds,': 2, 'learning': 2, 'come': 2, 'up': 2, 'number': 2, 'topic': 2, 'continuously': 2, 'moved': 2, 'coordinate': 2, 'legs,': 2, 'performing': 2, 'whole': 2, 'motion.': 2, 'effective': 2, 'laws,': 2, 'interrelationships,': 2, 'dynamics,': 2, 'atomic': 2, 'structures': 2, 'behavior': 2, 'maintenance': 2, 'kind': 2, 'job.': 2, 'sound': 2, 'presence': 2, 'plant': 2, 'system': 2, 'changes': 2, 'environment': 2, 'control,': 2, 'chemical': 2, 'methods.': 2, 'correct': 2, 'machines': 2, 'bend,': 2, 'stretch,': 2, 'twist,': 2, 'reach': 2, 'body,': 2, 'visual': 2, 'speed': 2, 'direction': 2, 'tools,': 2, 'tools': 2, 'response': 2, 'out': 2, 'judge': 2, 'from': 2, 'design': 2, 'various': 2, 'goods': 2, 'accounting': 2, 'practices,': 2, 'personnel': 2, 'product': 2, 'programs': 2, 'materials,': 2, 'distribution': 2, 'sea,': 2, 'financial': 2, 'products': 2, 'sales': 2, 'know': 2, 'providing': 1, 'personal': 1, 'assessment,': 1, 'meeting': 1, 'standards': 1, 'evaluation': 1, 'satisfaction.': 1, 'wrong': 1, 'likely': 1, 'go': 1, 'wrong.': 1, 'solving': 1, 'problem,': 1, 'only': 1, 'recognizing': 1, 'there': 1, 'listen': 1, 'through': 1, 'spoken': 1, 'words': 1, 'sentences.': 1, 'speaking': 1, 'close': 1, 'range': 1, '(within': 1, 'few': 1, 'feet': 1, 'observer).': 1, 'diagnose': 1, 'treat': 1, 'injuries,': 1, 'diseases,': 1, 'deformities.': 1, 'symptoms,': 1, 'alternatives,': 1, 'drug': 1, 'preventive': 1, 'health-care': 1, 'measures.': 1, 'giving': 1, 'full': 1, 'attention': 1, 'saying,': 1, 'taking': 1, 'p ...
